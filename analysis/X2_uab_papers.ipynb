# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
oa = pd.read_feather("../data/oa.feather")

def tslug(s):
    return re.sub('\W','',s).lower()
oa["tslug"] = oa["title"].astype(str).apply(tslug)
print(oa.shape)
# Out:
# (1026371, 7)

# %%
r_papers = pd.read_excel('../data/UA_annotated.xlsx')
r_papers
# Out:
#                                         Authors  \
# 0                     Whitley C.T.; Bowers M.M.
# 1                                   Okushima S.
# 2                Zhai X.; An Y.; Shi X.; Cui H.
# 3                       Rajeev M.; Nagendran P.
# 4                           Klebl C.; Jetten J.
# ..                                          ...
# 93                  Chung W.; Kam M.S.; Ip C.Y.
# 94      Kerkhof A.C.; Benders R.M.J.; Moll H.C.
# 95  Martinsson J.; Lundqvist L.J.; Sundström A.
# 96             Heinonen J.; Kyrö R.; Junnila S.
# 97                    Weber C.L.; Matthews H.S.
#
#                                     Author full names  \
# 0   Whitley, Cameron T. (55631000400); Bowers, Mel...
# 1                  Okushima, Shinichiro (17135732200)
# 2   Zhai, Xueqi (36702407100); An, Yunfei (5720565...
# 3   Rajeev, Meenakshi (6603195478); Nagendran, Pra...
# 4   Klebl, Christoph (57205755444); Jetten, Joland...
# ..                                                ...
# ...

# %%
r_papers = pd.read_excel('../data/UAB_papers_relevant.xlsx')
print(r_papers.shape)
r_papers = r_papers[r_papers['Year']<2023].reset_index(drop=True)
r_papers["tslug"] = r_papers["Title"].astype(str).apply(tslug)

print(r_papers.columns)

r_papers.shape
# Out:
# (98, 25)
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Abstract', 'Author Keywords',
#        'Index Keywords', 'Publisher', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID',
#        'tslug'],
#       dtype='object')
# (60, 26)

# %%
r_

# %%
r_papers.to_excel

# %%
r_papers.head()
# Out:
#                                Authors  \
# 0  Yazar M.; Hermwille L.; Haarstad H.
# 1                           Chancel L.
# 2           Gonenc H.; Krasnikova A.V.
# 3                 Alemu M.; Dessale M.
# 4                           Stewart F.
#
#                                    Author full names  \
# 0  Yazar, Mahir (57201992566); Hermwille, Lukas (...
# 1                       Chancel, Lucas (56074769500)
# 2  Gonenc, Halit (23392867000); Krasnikova, Anton...
# 3  Alemu, Melese (57416775000); Dessale, Moges (5...
# 4                      Stewart, Fraser (57207623430)
#
#                             Author(s) ID  \
# 0  57201992566; 56582265600; 16052709500
# 1                            56074769500
# 2               23392867000; 57961383100
# 3               57416775000; 57205321365
# 4                            57207623430
#
#                                                Title  Year  \
# 0  right-wing and populist support for climate mi...  2022
# ...

# %%
# !rsync -a ../data/UAB_papers_relevant.xlsx maxcall@cluster.pik-potsdam.de:policy-instruments/data/UAB_papers_relevant.xlsx

# %%
for i, row in r_papers.iterrows():
    print()
    print(row['Title'])
    print(row['Abstract'])
    if row['tslug'] not in oa['tslug']:
        print('Not in Oa')
# Out:
# right-wing and populist support for climate mitigation policies: evidence from poland and its carbon-intensive silesia region
# ...
